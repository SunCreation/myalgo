# %%
import os
lst = os.listdir()

# %%
name = 'hi'

# %%
# !mkdir file

# %%
for idx,i in enumerate(lst):
    with open(i, 'rb') as f:
        with open('file/'+name+str(idx),'wb') as g:
            g.write(f.read())

# %%
import pandas as pd
pd.read_csv('medical.csv',encoding='euc-kr')
# Out:
#     시도별(1)      2015  2015.1         2015.2         2015.3  \
# 0   시도별(1)        총계      총계  일반진료중심(광역 이상)  일반진료중심(광역 이상)
# 1   시도별(1)  기관수 (개소)  비율 (%)       기관수 (개소)         비율 (%)
# 2       전국       212   100.0             17          100.0
# 3       서울        21     9.9              2           11.8
# 4       부산        10     4.7              1            5.9
# 5       대구         8     3.8              2           11.8
# 6       인천         7     3.3              0            0.0
# 7       광주         8     3.8              2           11.8
# 8       대전         7     3.3              1            5.9
# 9       울산         1     0.5              0            0.0
# 10      세종         0     0.0              0            0.0
# 11      경기        30    14.2              2           11.8
# 12      강원        19     9.0              1            5.9
# 13      충북         9     4.2              1            5.9
# 14      충남        14     6.6              0            0.0
# ...
