# %%
from time import time

num_list = [f'p{i}' for i in range(1,17)]

start = time()

def count(name):
    for i in range(10000000):
        a = 1 + 2

    print('finish:'+name+"\n")

for i in num_list:
    count(i)

print('직렬 처리 time:', time() -start)


from multiprocessing import Pool
start = time()

if __name__=='__main__':
    pool = Pool(processes=16)
    pool.map(count, num_list)
    pool.close()
    pool.join()

print('병렬 처리 time:', time() -start)
# Out:
# finish:p1
#
# finish:p2
#
# finish:p3
#
# finish:p4
#
# finish:p5
#
# finish:p6
#
# finish:p7
#
# finish:p8
#
# finish:p9
#
# finish:p10
#
# finish:p11
#
# finish:p12
#
# finish:p13
#
# finish:p14
#
# finish:p15
#
# finish:p16
#
# 직렬 처리 time: 2.3087706565856934
# finish:p1
# finish:p11
#
# finish:p12
#
# finish:p2
#
# finish:p14
#
#
# finish:p3
# finish:p10
#
#
# finish:p9
# finish:p7
#
#
# finish:p13
# finish:p15
# finish:p4
#
# finish:p6
#
#
# finish:p8
#
#
# finish:p5
#
# finish:p16
#
# 병렬 처리 time: 0.41916656494140625
