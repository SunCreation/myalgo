# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %config InlineBackend.figure_format = 'retina'

# %%
import os

# %%
csv_path = 'data/Pokemon.csv'
data = pd.read_csv(csv_path)
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.shape
# Out:
# (800, 13)

# %%
mydata = data[['Type 1','Type 2']]
mydata.index = data['Name']
mydata.T
# Out:
# Name   Bulbasaur Ivysaur Venusaur VenusaurMega Venusaur Charmander Charmeleon  \
# Type 1     Grass   Grass    Grass                 Grass       Fire       Fire
# Type 2    Poison  Poison   Poison                Poison        NaN        NaN
#
# Name   Charizard CharizardMega Charizard X CharizardMega Charizard Y Squirtle  \
# Type 1      Fire                      Fire                      Fire    Water
# Type 2    Flying                    Dragon                    Flying      NaN
#
# Name    ...  Noibat Noivern Xerneas Yveltal Zygarde50% Forme Diancie  \
# Type 1  ...  Flying  Flying   Fairy    Dark           Dragon    Rock
# Type 2  ...  Dragon  Dragon     NaN  Flying           Ground   Fairy
#
# Name   DiancieMega Diancie HoopaHoopa Confined HoopaHoopa Unbound Volcanion
# Type 1                Rock             Psychic            Psychic      Fire
# Type 2               Fairy               Ghost               Dark     Water
#
# [2 rows x 800 columns]

# %%
legend = data[data['Legendary']].reset_index(drop=True)
legend
# Out:
#       #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0   144             Articuno       Ice    Flying    580   90      85      100
# 1   145               Zapdos  Electric    Flying    580   90      90       85
# 2   146              Moltres      Fire    Flying    580   90     100       90
# 3   150               Mewtwo   Psychic       NaN    680  106     110       90
# 4   150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..  ...                  ...       ...       ...    ...  ...     ...      ...
# 60  719              Diancie      Rock     Fairy    600   50     100      150
# 61  719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 62  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 63  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 64  721            Volcanion      Fire     Water    600   80     110      120
#
# ...

# %%
ordinary = data[data['Legendary']==False].reset_index()
